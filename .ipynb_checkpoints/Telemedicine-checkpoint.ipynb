# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Use_of_Telemedicine_During_COVID-19.csv")

# %%
data
# Out:
#      Round                                        Indicator  \
# 0        1                     Provider offers telemedicine
# 1        1                     Provider offers telemedicine
# 2        1                     Provider offers telemedicine
# 3        1                     Provider offers telemedicine
# 4        1                     Provider offers telemedicine
# ..     ...                                              ...
# 527      2  Provider offered telemedicine prior to pandemic
# 528      2  Provider offered telemedicine prior to pandemic
# 529      2  Provider offered telemedicine prior to pandemic
# 530      2  Provider offered telemedicine prior to pandemic
# 531      2  Provider offered telemedicine prior to pandemic
#
#                   Group        Subgroup  Sample Size                Response  \
# 0                 Total           Total       6786.0                   Total
# 1                 Total           Total          NaN                     Yes
# 2                 Total           Total          NaN                      No
# 3                 Total           Total          NaN             Do not know
# 4                 Total           Total          NaN  No usual place of care
# ..                  ...             ...          ...                     ...
# 527  Chronic conditions  Current asthma        618.0                   Total
# 528  Chronic conditions  Current asthma          NaN                     Yes
# 529  Chronic conditions  Current asthma          NaN                      No
# 530  Chronic conditions  Current asthma          NaN             Do not know
# 531  Chronic conditions  Current asthma          NaN  No usual place of care
#
#      Percent  Standard Error Suppression  Significant
# 0      100.0             NaN         NaN          NaN
# 1       36.6             0.8         NaN          NaN
# 2       46.9             0.8         NaN          NaN
# 3        5.2             0.4         NaN          NaN
# 4       11.3             0.7         NaN          NaN
# ..       ...             ...         ...          ...
# 527    100.0             NaN         NaN          NaN
# 528     16.0             1.2         NaN          0.0
# 529     63.6             2.2         NaN          0.0
# 530     11.8             2.3         NaN          0.0
# 531      8.6             1.4         NaN          0.0
#
# [532 rows x 10 columns]

# %% [markdown]
# # Descriptions
#
# ## Round : Data collection period; round 1 occurred June 9, 2020–July 6, 2020 and round 2 occurred August 3, 2020–August 20, 2020
#
# ## Indicator: Indicators include 1) provider offers telemedicine, 2) scheduled one or more telemedicine appointments, and 3) provider offered telemedicine prior to pandemic.
#
# ## Group: Estimates were reported at the national level (total) and by age group, race and Hispanic origin, sex, education level, urbanization, and selected chronic conditions.
#
# ## Subgroup: Subcategories for each group
#
# ## Sample Size: Sample Size
#
# ## Response: Survey question response for each indicator
#
# ## Percent: Percent estimate
#
# ## Standard Error: Standard error estimate
#
# ## Supression: Identifies percent and standard Error estimates that did not meet NCHS Data Presentation Standards for Proportions
#
# ## Significant: Indicator for significance testing between rounds 1 and 2 estimates where a value of 0 indicates the estimates from rounds 1 and 2 are not statistically significantly different at the 5% significance level and a value of 1 indicates that the estimates from rounds 1 and 2 are statistically significantly different at the 5% significance level. More information on the statistical test used and the interpretation of the results can be found in the study technical notes (https://www.cdc.gov/nchs/covid19/rands/telemedicine.htm#limitations).
#
#
# # All descriptions were got from https://data.cdc.gov/NCHS/Use-of-Telemedicine-During-COVID-19/8xy9-ubqz

# %%
data.count()
# Out:
# Round             532
# Indicator         532
# Group             532
# Subgroup          532
# Sample Size       114
# Response          532
# Percent           530
# Standard Error    416
# Suppression         2
# Significant       207
# dtype: int64

# %%
round_one = data.loc[data['Round'] == 1]

# %%
round_one
# Out:
#      Round                                        Indicator  \
# 0        1                     Provider offers telemedicine
# 1        1                     Provider offers telemedicine
# 2        1                     Provider offers telemedicine
# 3        1                     Provider offers telemedicine
# 4        1                     Provider offers telemedicine
# ..     ...                                              ...
# 432      1  Provider offered telemedicine prior to pandemic
# 433      1  Provider offered telemedicine prior to pandemic
# 434      1  Provider offered telemedicine prior to pandemic
# 435      1  Provider offered telemedicine prior to pandemic
# 436      1  Provider offered telemedicine prior to pandemic
#
#                   Group        Subgroup  Sample Size                Response  \
# 0                 Total           Total       6786.0                   Total
# 1                 Total           Total          NaN                     Yes
# 2                 Total           Total          NaN                      No
# 3                 Total           Total          NaN             Do not know
# 4                 Total           Total          NaN  No usual place of care
# ..                  ...             ...          ...                     ...
# 432  Chronic conditions  Current asthma        698.0                   Total
# 433  Chronic conditions  Current asthma          NaN                     Yes
# 434  Chronic conditions  Current asthma          NaN                      No
# 435  Chronic conditions  Current asthma          NaN             Do not know
# 436  Chronic conditions  Current asthma          NaN  No usual place of care
#
#      Percent  Standard Error Suppression  Significant
# 0      100.0             NaN         NaN          NaN
# 1       36.6             0.8         NaN          NaN
# 2       46.9             0.8         NaN          NaN
# 3        5.2             0.4         NaN          NaN
# 4       11.3             0.7         NaN          NaN
# ..       ...             ...         ...          ...
# 432    100.0             NaN         NaN          NaN
# 433     18.3             2.0         NaN          NaN
# 434     64.3             1.8         NaN          NaN
# 435      9.1             1.4         NaN          NaN
# 436      8.2             1.6         NaN          NaN
#
# [266 rows x 10 columns]

# %%
round_two = data.loc[data['Round'] == 2]

# %%
round_two
# Out:
#      Round                                        Indicator  \
# 95       2                     Provider offers telemedicine
# 96       2                     Provider offers telemedicine
# 97       2                     Provider offers telemedicine
# 98       2                     Provider offers telemedicine
# 99       2                     Provider offers telemedicine
# ..     ...                                              ...
# 527      2  Provider offered telemedicine prior to pandemic
# 528      2  Provider offered telemedicine prior to pandemic
# 529      2  Provider offered telemedicine prior to pandemic
# 530      2  Provider offered telemedicine prior to pandemic
# 531      2  Provider offered telemedicine prior to pandemic
#
#                   Group        Subgroup  Sample Size                Response  \
# 95                Total           Total       5972.0                   Total
# 96                Total           Total          NaN                     Yes
# 97                Total           Total          NaN                      No
# 98                Total           Total          NaN             Do not know
# 99                Total           Total          NaN  No usual place of care
# ..                  ...             ...          ...                     ...
# 527  Chronic conditions  Current asthma        618.0                   Total
# 528  Chronic conditions  Current asthma          NaN                     Yes
# 529  Chronic conditions  Current asthma          NaN                      No
# 530  Chronic conditions  Current asthma          NaN             Do not know
# 531  Chronic conditions  Current asthma          NaN  No usual place of care
#
#      Percent  Standard Error Suppression  Significant
# 95     100.0             NaN         NaN          NaN
# 96      37.1             0.7         NaN          0.0
# 97      48.0             0.9         NaN          0.0
# 98       5.4             0.4         NaN          0.0
# 99       9.5             0.7         NaN          1.0
# ..       ...             ...         ...          ...
# 527    100.0             NaN         NaN          NaN
# 528     16.0             1.2         NaN          0.0
# 529     63.6             2.2         NaN          0.0
# 530     11.8             2.3         NaN          0.0
# 531      8.6             1.4         NaN          0.0
#
# [266 rows x 10 columns]

# %%
round_two_y = round_two.loc[round_two['Response'] =="Yes"]

# %%
round_two_y
# Out:
#      Round                                        Indicator  \
# 96       2                     Provider offers telemedicine
# 101      2                     Provider offers telemedicine
# 106      2                     Provider offers telemedicine
# 111      2                     Provider offers telemedicine
# 116      2                     Provider offers telemedicine
# 121      2                     Provider offers telemedicine
# 126      2                     Provider offers telemedicine
# 131      2                     Provider offers telemedicine
# 136      2                     Provider offers telemedicine
# 141      2                     Provider offers telemedicine
# 146      2                     Provider offers telemedicine
# 151      2                     Provider offers telemedicine
# 156      2                     Provider offers telemedicine
# 161      2                     Provider offers telemedicine
# 166      2                     Provider offers telemedicine
# 171      2                     Provider offers telemedicine
# 176      2                     Provider offers telemedicine
# 181      2                     Provider offers telemedicine
# 186      2                     Provider offers telemedicine
# 267      2  Scheduled one or more telemedicine appointments
# 271      2  Scheduled one or more telemedicine appointments
# 275      2  Scheduled one or more telemedicine appointments
# 279      2  Scheduled one or more telemedicine appointments
# 283      2  Scheduled one or more telemedicine appointments
# 287      2  Scheduled one or more telemedicine appointments
# 291      2  Scheduled one or more telemedicine appointments
# 295      2  Scheduled one or more telemedicine appointments
# 299      2  Scheduled one or more telemedicine appointments
# 303      2  Scheduled one or more telemedicine appointments
# 307      2  Scheduled one or more telemedicine appointments
# 311      2  Scheduled one or more telemedicine appointments
# 315      2  Scheduled one or more telemedicine appointments
# 319      2  Scheduled one or more telemedicine appointments
# 323      2  Scheduled one or more telemedicine appointments
# 327      2  Scheduled one or more telemedicine appointments
# 331      2  Scheduled one or more telemedicine appointments
# 335      2  Scheduled one or more telemedicine appointments
# 339      2  Scheduled one or more telemedicine appointments
# 438      2  Provider offered telemedicine prior to pandemic
# 443      2  Provider offered telemedicine prior to pandemic
# 448      2  Provider offered telemedicine prior to pandemic
# 453      2  Provider offered telemedicine prior to pandemic
# 458      2  Provider offered telemedicine prior to pandemic
# 463      2  Provider offered telemedicine prior to pandemic
# 468      2  Provider offered telemedicine prior to pandemic
# 473      2  Provider offered telemedicine prior to pandemic
# 478      2  Provider offered telemedicine prior to pandemic
# 483      2  Provider offered telemedicine prior to pandemic
# 488      2  Provider offered telemedicine prior to pandemic
# 493      2  Provider offered telemedicine prior to pandemic
# 498      2  Provider offered telemedicine prior to pandemic
# 503      2  Provider offered telemedicine prior to pandemic
# 508      2  Provider offered telemedicine prior to pandemic
# 513      2  Provider offered telemedicine prior to pandemic
# 518      2  Provider offered telemedicine prior to pandemic
# 523      2  Provider offered telemedicine prior to pandemic
# 528      2  Provider offered telemedicine prior to pandemic
#
#                     Group                        Subgroup  Sample Size  \
# 96                  Total                           Total          NaN
# 101             Age group                     18-44 years          NaN
# 106             Age group                     45-64 years          NaN
# 111             Age group               65 years and over          NaN
# 116  Race/Hispanic origin              White non-Hispanic          NaN
# 121  Race/Hispanic origin              Black non-Hispanic          NaN
# 126  Race/Hispanic origin              Other non-Hispanic          NaN
# 131  Race/Hispanic origin                        Hispanic          NaN
# 136                   Sex                            Male          NaN
# 141                   Sex                          Female          NaN
# 146             Education    High school graduate or less          NaN
# 151             Education                    Some college          NaN
# 156             Education      Bachelor's degree or above          NaN
# 161          Urbanization                    Metropolitan          NaN
# 166          Urbanization                Non-Metropolitan          NaN
# 171    Chronic conditions  One or more chronic conditions          NaN
# 176    Chronic conditions              Diagnosed diabetes          NaN
# 181    Chronic conditions          Diagnosed hypertension          NaN
# 186    Chronic conditions                  Current asthma          NaN
# 267                 Total                           Total          NaN
# 271             Age group                     18-44 years          NaN
# 275             Age group                     45-64 years          NaN
# 279             Age group               65 years and over          NaN
# 283  Race/Hispanic origin              White non-Hispanic          NaN
# 287  Race/Hispanic origin              Black non-Hispanic          NaN
# 291  Race/Hispanic origin              Other non-Hispanic          NaN
# 295  Race/Hispanic origin                        Hispanic          NaN
# 299                   Sex                            Male          NaN
# 303                   Sex                          Female          NaN
# 307             Education    High school graduate or less          NaN
# 311             Education                    Some college          NaN
# 315             Education      Bachelor's degree or above          NaN
# 319          Urbanization                    Metropolitan          NaN
# 323          Urbanization                Non-Metropolitan          NaN
# 327    Chronic conditions  One or more chronic conditions          NaN
# 331    Chronic conditions              Diagnosed diabetes          NaN
# 335    Chronic conditions          Diagnosed hypertension          NaN
# 339    Chronic conditions                  Current asthma          NaN
# 438                 Total                           Total          NaN
# 443             Age group                     18-44 years          NaN
# 448             Age group                     45-64 years          NaN
# 453             Age group               65 years and over          NaN
# 458  Race/Hispanic origin              White non-Hispanic          NaN
# 463  Race/Hispanic origin              Black non-Hispanic          NaN
# 468  Race/Hispanic origin              Other non-Hispanic          NaN
# 473  Race/Hispanic origin                        Hispanic          NaN
# 478                   Sex                            Male          NaN
# 483                   Sex                          Female          NaN
# 488             Education    High school graduate or less          NaN
# 493             Education                    Some college          NaN
# 498             Education      Bachelor's degree or above          NaN
# 503          Urbanization                    Metropolitan          NaN
# 508          Urbanization                Non-Metropolitan          NaN
# 513    Chronic conditions  One or more chronic conditions          NaN
# 518    Chronic conditions              Diagnosed diabetes          NaN
# 523    Chronic conditions          Diagnosed hypertension          NaN
# 528    Chronic conditions                  Current asthma          NaN
#
#     Response  Percent  Standard Error Suppression  Significant
# 96       Yes     37.1             0.7         NaN          0.0
# 101      Yes     31.2             0.9         NaN          0.0
# 106      Yes     40.1             1.3         NaN          0.0
# 111      Yes     45.6             1.7         NaN          0.0
# 116      Yes     37.9             1.3         NaN          0.0
# 121      Yes     40.0             1.7         NaN          0.0
# 126      Yes     34.4             3.4         NaN          0.0
# 131      Yes     33.1             2.8         NaN          0.0
# 136      Yes     33.4             1.0         NaN          0.0
# 141      Yes     40.5             0.8         NaN          0.0
# 146      Yes     33.3             1.4         NaN          0.0
# 151      Yes     37.6             1.1         NaN          0.0
# 156      Yes     40.8             1.3         NaN          0.0
# 161      Yes     38.0             0.7         NaN          0.0
# 166      Yes     30.3             2.7         NaN          0.0
# 171      Yes     44.5             0.8         NaN          0.0
# 176      Yes     55.2             2.9         NaN          0.0
# 181      Yes     47.1             1.3         NaN          0.0
# 186      Yes     44.6             2.3         NaN          0.0
# 267      Yes     24.3             0.7         NaN          0.0
# 271      Yes     20.8             0.9         NaN          0.0
# 275      Yes     25.9             1.1         NaN          0.0
# 279      Yes     29.5             1.4         NaN          0.0
# 283      Yes     24.2             1.0         NaN          0.0
# 287      Yes     28.9             1.8         NaN          0.0
# 291      Yes     22.6             2.6         NaN          0.0
# 295      Yes     21.9             2.5         NaN          0.0
# 299      Yes     20.4             0.8         NaN          0.0
# 303      Yes     27.9             0.9         NaN          0.0
# 307      Yes     21.9             1.5         NaN          0.0
# 311      Yes     25.8             1.1         NaN          0.0
# 315      Yes     25.5             1.0         NaN          0.0
# 319      Yes     25.0             0.7         NaN          0.0
# 323      Yes     18.7             2.1         NaN          1.0
# 327      Yes     30.1             1.0         NaN          0.0
# 331      Yes     41.6             3.1         NaN          0.0
# 335      Yes     32.7             1.4         NaN          0.0
# 339      Yes     32.4             2.4         NaN          0.0
# 438      Yes     14.1             0.7         NaN          0.0
# 443      Yes     14.0             1.0         NaN          0.0
# 448      Yes     14.3             0.8         NaN          0.0
# 453      Yes     14.0             1.1         NaN          0.0
# 458      Yes     12.4             0.6         NaN          0.0
# 463      Yes     18.1             1.8         NaN          0.0
# 468      Yes     16.0             2.1         NaN          0.0
# 473      Yes     17.0             2.6         NaN          0.0
# 478      Yes     14.3             1.0         NaN          0.0
# 483      Yes     14.0             1.0         NaN          0.0
# 488      Yes     13.3             1.4         NaN          0.0
# 493      Yes     14.8             1.1         NaN          0.0
# 498      Yes     14.3             0.8         NaN          0.0
# 503      Yes     14.7             0.7         NaN          0.0
# 508      Yes      9.4             0.9         NaN          0.0
# 513      Yes     15.4             0.8         NaN          0.0
# 518      Yes     18.0             2.2         NaN          0.0
# 523      Yes     16.0             1.0         NaN          0.0
# 528      Yes     16.0             1.2         NaN          0.0

# %%
plt.barh(round_two_y['Indicator'].loc[round_two_y['Subgroup'] == '18-44 years'], round_two_y['Percent'].loc[round_two_y['Subgroup'] == '18-44 years'])
# Out:
# <BarContainer object of 3 artists>

# %%
round_two['Percent'].loc[round_two['Subgroup'] == '18-44 years']
# Out:
# 101    31.2
# 271    20.8
# 443    14.0
# Name: Percent, dtype: float64
